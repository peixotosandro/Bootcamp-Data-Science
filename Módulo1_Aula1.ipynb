# %%
import pandas as pd

# %%
dados = pd.read_csv("/content/A154353189_28_143_208.csv",encoding="ISO-8859-1", skiprows=3, 
                    sep=";",skipfooter=12, thousands=".", decimal=",")
dados
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#       Unidade da Federação      2008/Jan  ...       2021/Mar             Total
# 0              11 Rondônia  1,388,528.39  ...  11,023,309.47    996,411,254.68
# 1                  12 Acre    902,416.00  ...   4,077,045.92    450,048,530.47
# 2              13 Amazonas  4,735,529.42  ...  22,032,176.22  1,917,247,936.05
# 3               14 Roraima    657,889.53  ...   3,985,530.08    328,876,965.09
# 4                  15 Pará 18,864,744.11  ...  33,276,392.89  4,705,309,002.29
# 5                 16 Amapá  1,120,973.34  ...   3,188,210.98    309,860,092.59
# 6             17 Tocantins  3,441,592.69  ...   1,357,751.33  1,020,028,272.64
# 7              21 Maranhão 10,723,506.39  ...  39,663,677.48  3,871,069,498.04
# 8                 22 Piauí  7,985,142.43  ...  20,018,325.75  2,280,888,802.74
# 9                 23 Ceará 15,539,821.90  ...  62,079,618.54  6,591,836,650.18
# 10  24 Rio Grande do Norte  5,947,814.08  ...  23,306,498.68  2,660,122,027.15
# 11              25 Paraíba 10,723,002.45  ...  25,750,897.89  2,614,919,044.63
# 12           26 Pernambuco 14,393,949.89  ...  83,870,992.73  8,581,189,975.91
# 13              27 Alagoas  6,243,726.32  ...  22,118,639.05  2,236,415,402.51
# 14              28 Sergipe  2,780,750.11  ...  13,321,494.41  1,215,853,015.00
# 15                29 Bahia 21,211,522.47  ...  98,746,333.07  9,791,541,570.52
# 16         31 Minas Gerais 45,671,659.76  ... 200,471,045.07 20,418,737,536.66
# 17       32 Espírito Santo  5,456,723.98  ...  45,490,499.45  3,405,850,698.58
# 18       33 Rio de Janeiro 23,025,258.52  ... 106,837,295.81 10,337,391,164.52
# 19            35 São Paulo 91,678,473.48  ... 392,946,147.42 41,396,604,304.13
# 20               41 Paraná 38,266,347.46  ... 140,264,608.52 14,681,514,706.67
# 21       42 Santa Catarina 16,504,913.45  ...  81,376,630.57  7,835,011,163.40
# 22    43 Rio Grande do Sul 30,931,325.46  ... 130,155,185.16 12,764,391,179.92
# 23   50 Mato Grosso do Sul  5,377,392.11  ...  25,168,195.34  2,324,525,096.33
# 24          51 Mato Grosso  4,795,299.01  ...  19,611,032.61  2,180,119,781.15
# 25                52 Goiás 15,310,637.29  ...  45,592,686.49  4,973,573,613.47
# 26     53 Distrito Federal  4,745,919.19  ...  31,831,917.45  2,592,422,853.56
#
# [27 rows x 161 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 161 entries, Unidade da Federação to Total
# dtypes: float64(159), object(2)
# memory usage: 34.1+ KB

# %%
dados.mean()
# Out:
# 2008/Jan    1.512685e+07
# 2008/Fev    2.271016e+07
# 2008/Mar    2.459419e+07
# 2008/Abr    2.543196e+07
# 2008/Mai    2.651125e+07
#                 ...
# 2020/Dez    5.337776e+07
# 2021/Jan    5.607375e+07
# 2021/Fev    5.557823e+07
# 2021/Mar    6.250230e+07
# Total       6.388213e+09
# Length: 159, dtype: float64

# %%
pd.options.display.float_format = "{:,.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan      15,126,846.64
# 2008/Fev      22,710,158.12
# 2008/Mar      24,594,187.35
# 2008/Abr      25,431,957.83
# 2008/Mai      26,511,245.91
#                  ...
# 2020/Dez      53,377,763.15
# 2021/Jan      56,073,748.02
# 2021/Fev      55,578,233.31
# 2021/Mar      62,502,301.42
# Total      6,388,213,338.48
# Length: 159, dtype: float64

# %%
dados['2008/Ago']
# Out:
# 0      3,231,494.61
# 1      2,089,107.14
# 2      9,352,532.70
# 3        894,271.18
# 4     23,341,218.03
# 5      1,475,551.38
# 6      5,413,710.38
# 7     15,195,312.89
# 8     10,549,176.40
# 9     27,851,438.72
# 10    10,640,817.47
# 11    12,872,578.37
# 12    35,457,038.66
# 13     9,373,432.00
# 14     5,238,398.50
# 15    46,931,248.28
# 16    84,722,528.10
# 17    12,588,595.77
# 18    50,912,706.60
# 19   184,854,516.35
# 20    56,982,774.90
# 21    31,250,854.33
# 22    56,113,054.70
# 23     9,671,553.45
# 24     9,243,148.81
# 25    20,650,730.67
# 26    13,710,857.89
# Name: 2008/Ago, dtype: float64

# %%
dados['2008/Ago'].mean()
# Out:
# 27800320.306666665

# %%
dados.plot(x="Unidade da Federação",y="2008/Ago", kind="bar", figsize=(9,6))

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação",y="2008/Ago", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor por unidade da federação")
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

ax = dados.plot(x="Unidade da Federação",y="2021/Mar", kind="bar", figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))

plt.title("Valor total por Ano/mês processamento segundo Unidade da Federação")
plt.show()
